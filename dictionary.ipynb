# %%
dict = {'india': 'delhi','china':'beijing','germany':'berlin','france':'paris'}
dict
# Out:
# {'india': 'delhi', 'china': 'beijing', 'germany': 'berlin', 'france': 'paris'}

# %%
dict['india']
# Out:
# 'delhi'

# %%
dict['japan']= 'tokyo'
print(dict)
# Out:
# {'india': 'delhi', 'china': 'beijing', 'germany': 'berlin', 'france': 'paris', 'japan': 'tokyo'}

# %%
dict['USA']= 'new york'
print(dict)
# Out:
# {'india': 'delhi', 'china': 'beijing', 'germany': 'berlin', 'france': 'paris', 'japan': 'tokyo', 'USA': 'new york'}

# %%
del dict['france']
print(dict)
# Out:
# {'india': 'delhi', 'china': 'beijing', 'germany': 'berlin', 'japan': 'tokyo', 'USA': 'new york'}

# %%
students = {'rahul':85,'anita':92,'awani':95,'poornima':95}
print(students)
# Out:
# {'rahul': 85, 'anita': 92, 'awani': 95, 'poornima': 95}

# %%
print(students.values())
# Out:
# dict_values([85, 92, 95, 95])

# %%
print(students.items())
# Out:
# dict_items([('rahul', 85), ('anita', 92), ('awani', 95), ('poornima', 95)])

# %%
print(students['rahul'])
# Out:
# 85

# %%
students.update({'falak':100, 'antra':88})
print(students)
# Out:
# {'rahul': 85, 'anita': 92, 'awani': 95, 'poornima': 95, 'falak': 100, 'antra': 88}

# %%
students.pop('anita')
# Out:
# 92

# %%
countries = {'india':'delhi','germany':'berlin','france':'paris'}
countries.pop('germany')
print(countries)
# Out:
# {'india': 'delhi', 'france': 'paris'}

# %%
countries.pop('japan','key not found')
print(countries)
# Out:
# {'india': 'delhi', 'france': 'paris'}

# %%
countries.clear()
print(countries)
# Out:
# {}
