# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt") as file:
    content = file.read()
    print(content)
# Out:
# Falak, 20, Lucknow
# Mahak, 20, Delhi
# Awani, 19, Noida
# Poornima, 21, Kanpur

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt", 'r') as file:
    content = file.readline()
    print(content)
# Out:
# Falak, 20, Lucknow

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt", 'r') as file:
    lines = file.readlines()
    print(lines)
    file.close()
# Out:
# ['Falak, 20, Lucknow\n', 'Mahak, 20, Delhi\n', 'Awani, 19, Noida\n', 'Poornima, 21, Kanpur\n']

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt", 'r') as file:
    lines = file.readlines()
    for line in lines:
        print(line.strip())
# Out:
# Falak, 20, Lucknow
# Mahak, 20, Delhi
# Awani, 19, Noida
# Poornima, 21, Kanpur

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt", 'r') as file:
    count=0
    for line in file:
        count += 1
        print("number of lines", count)
# Out:
# number of lines 1
# number of lines 2
# number of lines 3
# number of lines 4

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt", "w") as file:
    file.write("Falak, 20, Lucknow\n")
    file.write("Mahak, 20, Delhi\n")
    file.write("Awani, 19, Noida\n")

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt", 'r') as file:
    content = file.read()
    print(content)
# Out:
# Falak, 20, Lucknow
# Mahak, 20, Delhi
# Awani, 19, Noida

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt", "a") as file:
    file.write("Karan, 23, Pune\n")

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt", 'r') as file:
    print(file.read())
    file.close()
# Out:
# Falak, 20, Lucknow
# Mahak, 20, Delhi
# Awani, 19, Noida
# Karan, 23, Pune

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt", "r+") as file:
    data = file.read()
    data = data.replace("Amit", "Amit Kumar", 1)
    file.seek(0)
    file.write(data)
    file.close()

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\students.txt", "r+") as file:
    file.seek(0, 2)
    file.write("Sneha, 20, Hyderabad\n")
    file.close()
