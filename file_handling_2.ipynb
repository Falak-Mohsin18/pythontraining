# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r") as file:
    data = file.read()
    print(data)
# Out:
# P101, Laptop, 55000, Electronics
# P102, Mouse, 800, Electronics
# P103, Chair, 3000, Furniture
# P104, Table, 7000, Furniture
# P105, Mobile, 25000, Electronics

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r") as file:
    first_line = file.readline()
    print(first_line)
# Out:
# P101, Laptop, 55000, Electronics

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r") as file:
    lines = file.readlines()
    print(lines)
# Out:
# ['P101, Laptop, 55000, Electronics\n', 'P102, Mouse, 800, Electronics\n', 'P103, Chair, 3000, Furniture\n', 'P104, Table, 7000, Furniture\n', 'P105, Mobile, 25000, Electronics']

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r") as file:
    for line in file:
        print(line)
# Out:
# P101, Laptop, 55000, Electronics
#
# P102, Mouse, 800, Electronics
#
# P103, Chair, 3000, Furniture
#
# P104, Table, 7000, Furniture
#
# P105, Mobile, 25000, Electronics

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r") as file:
    count = 0
    for line in file:
        count+=1
        print("number of lines:", count)
# Out:
# number of lines: 1
# number of lines: 2
# number of lines: 3
# number of lines: 4
# number of lines: 5

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r") as file:
    for line in file:
        parts = line.split(",")
        print(parts)
# Out:
# ['P101', ' Laptop', ' 55000', ' Electronics\n']
# ['P102', ' Mouse', ' 800', ' Electronics\n']
# ['P103', ' Chair', ' 3000', ' Furniture\n']
# ['P104', ' Table', ' 7000', ' Furniture\n']
# ['P105', ' Mobile', ' 25000', ' Electronics']

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r") as file:
    for line in file:
        parts = line.split(",")
        price = int(parts[2])
        if price>10000:
            print(price)
# Out:
# 55000
# 25000

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","w") as file:
    file.write("P201, Headphones, 2000, Electronics\n")
    file.write("P202, Sofa, 28000, Furniture\n")
    file.write("P203, Printer, 12000, Electronics\n")

file.close()

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r") as file:
    data = file.read()
    print(data)
# Out:
# P201, Headphones, 2000, Electronics
# P202, Sofa, 28000, Furniture
# P203, Printer, 12000, Electronics

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","a") as file:
    file.write("P204, Desk Lamp, 3500, Electronics\n")
    file.close()

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r") as file:
    data = file.read()
    print(data)
# Out:
# P201, Headphones, 2000, Electronics
# P202, Sofa, 28000, Furniture
# P203, Printer, 12000, Electronics
# P204, Desk Lamp, 3500, Electronics

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r+") as file:
    data = file.read()
    data = data.replace("Mouse","Wireless Mouse")
    file.seek(0)
    file.write(data)
    file.close()

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r+") as file:
    file.seek(0,2)
    file.write("P205, Bed, 45000, Furniture\n")
    file.close()

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r") as file:
    data = file.read()
    print(data)
# Out:
# P201, Headphones, 2000, Electronics
# P202, Sofa, 28000, Furniture
# P203, Printer, 12000, Electronics
# P204, Desk Lamp, 3500, Electronics
# P205, Bed, 45000, Furniture

# %%
with open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r+") as file:
    count =0
    for line in file:
        if "Electronics" in line:
            count+=1
            print("number of Electronic products:", count)
# Out:
# number of Electronic products: 1
# number of Electronic products: 2
# number of Electronic products: 3

# %%
file = open(r"C:\Users\Ghazal\OneDrive\Desktop\Products.txt","r")
new_file = open("expensive_products.txt","w")
for line in file:
    data = line.strip().split(",")
    prince = int(data[2])
    if price>20000:
        new_file.write(line)
file.close()
new_file.close()
