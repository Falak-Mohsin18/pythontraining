# %%
set = {'red','orange','yellow','green','blue'}
print(set)
# Out:
# {'blue', 'red', 'green', 'yellow', 'orange'}

# %%
numbers = {1,2,3,4,5,6,1,1,1,2,2,3,4,4,5,5,5,7,8,7,6,}
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
fruits = {'apple','banana','cherry'}
for items in fruits:
    print(items)
# Out:
# apple
# banana
# cherry

# %%
fruits = {'apple','banana','cherry'}
fruits.add('orange')
print(fruits)
# Out:
# {'apple', 'banana', 'cherry', 'orange'}

# %%
fruits = {'apple','banana','cherry','orange'}
fruits.remove('banana')
print(fruits)
# Out:
# {'apple', 'cherry', 'orange'}

# %%
fruits = {'apple','banana','cherry','orange'}
fruits.pop()
print(fruits)
# Out:
# {'banana', 'cherry', 'orange'}

# %%
fruits = {'apple','banana','cherry','orange'}
fruits.discard('kiwi')
print(fruits)
# Out:
# {'apple', 'banana', 'cherry', 'orange'}

# %%
A={1,2,3}
B ={3,4,5,6}
print(A.union(B))
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
A={1,2,3}
B ={3,4,5,6}
print(A&B)
# Out:
# {3}

# %%
A={1,2,3}
B ={3,4,5,6}
print(A-B)
# Out:
# {1, 2}

# %%
B ={3,4,5,6}
print(B.copy())
# Out:
# {3, 4, 5, 6}

# %%
B ={3,4,5,6}
print(B.clear())
# Out:
# None

# %%
del set

# %%
mylist= {1,2,2,3,3,3,4,4,4,4,5}
uniquelist = set(mylist)
print(uniquelist)
# Out:
# {1, 2, 3, 4, 5}

# %%
text =  input("enter a string:")
unique = set(text)
print(unique)
# Out:
# {'p', 'g', 'm', 'a', ' ', 'u', 'k', 'h', 'e', 'l'}

# %%
cricket = {"player1","player2" , "player3"}
hockey = {"player3","player4" , "player5","player6"}
both = cricket&hockey
print(both)
# Out:
# {'player3'}

# %%
cricket = {"player1","player2" , "player3"}
hockey = {"player3","player4" , "player5","player6"}
both = cricket-hockey
print(both)
# Out:
# {'player1', 'player2'}

# %%
sentence=input('enter a string:')
words =  sentence.split()
unique = set(words)
print(unique)
# Out:
# {'am', 'paglu', 'i'}

# %%
set1= {1,2,3,4,5}
set2 = {5,4,6,7,8}
if set1==set2:
    print('equals')
else:
    print("not equal")
# Out:
# not equal

# %%
set1= {1,2,3,4,5}
set2 = {5,4,6,7,8}
common= set1&set2
if common:
    print("have common")
else:
    print("not common")
# Out:
# have common
